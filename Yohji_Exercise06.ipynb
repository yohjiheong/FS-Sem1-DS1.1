# %% [markdown]
# EXERCISE 6
# ==
# ## Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Question 1
#
# UFO (Unidentified Flying Objects) data is from http://www.nuforc.org/webreports.html.
#
# Given the UFO sightings data and the path for csv file, read the csv file from the URL.

# %%
path ='http://bit.ly/uforeports'

# %% [markdown]
# use the read_csv to read the csv and assign to a variable called 'ufo'

# %%
#read csv

ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
#show the top 5 rows of data
top5 = ufo.head(5)
top5
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#show the last 10 rows of data
last10 = ufo.tail(10)
last10
# Out:
#                  City Colors Reported Shape Reported State              Time
# 18231     Pismo Beach             NaN           OVAL    CA  12/31/2000 20:00
# 18232            Lodi             NaN            NaN    WI  12/31/2000 20:30
# 18233       Anchorage             RED        VARIOUS    AK  12/31/2000 21:00
# 18234        Capitola             NaN       TRIANGLE    CA  12/31/2000 22:00
# 18235  Fountain Hills             NaN            NaN    AZ  12/31/2000 23:00
# 18236      Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237     Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238     Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239     Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240            Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
#check the data type

type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
#check the data type for 'Time' column
ufo['Time'].dtypes
# Out:
# dtype('O')

# %%
#show all rows for the column 'City'
ufo2 = ufo.copy()
len(ufo2.drop_duplicates(subset = 'City'))
# Out:
# 6477

# %%
#determine the shape of the data
ufo.shape
# Out:
# (18241, 5)

# %%
#Extra
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
#show all data for 'City' that starts with 'E'

#ce = (ufo.groupby(['City']))
#ce[ce['City'] == 'E']

#ufo['City'] = ['City' if ['City'][0] == 'E' for c in ufo['City']]
#ufo['City']

#ufoc = ufo[ufo['City'].apply(lambda x: x.startswith('E'))]
#ufoc

#x = [start for start in ufo if ufo['City'] == 'E']

ufo['City'].loc[ufo['City'].str.startswith('E',na=False)]
# Out:
# 8               Eklutna
# 55             Espanola
# 109           Excelsior
# 140      East Palestine
# 179           Evergreen
#               ...
# 18182        Evansville
# 18215          El Campo
# 18224           Eufaula
# 18238       Eagle River
# 18239       Eagle River
# Name: City, Length: 557, dtype: object

# %%
# count number of reported cases for 'CIRCLE'
# and count the number of reported cases for 'LIGHT'
print (ufo['Shape Reported'].value_counts())
print('\n')
print ((ufo['Shape Reported'].value_counts())[0])
print ((ufo['Shape Reported'].value_counts())[4])
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# HEXAGON         1
# PYRAMID         1
# FLARE           1
# DOME            1
# Name: Shape Reported, dtype: int64
#
#
# 2803
# 1365

# %%
#determine what are the top three colors reported

ufo['Colors Reported'].value_counts().head(3)
# Out:
# RED       780
# GREEN     531
# ORANGE    528
# Name: Colors Reported, dtype: int64

# %%
#count the number of shape reported by state and city

ufo.groupby(['State','City'])['Shape Reported'].count()
# Out:
# State  City
# AK     Adak                          1
#        Alaska                        2
#        Anchorage                    12
#        Arctic                        1
#        Auke Bay                      2
#                                     ..
# WY     Ten Sleep                     1
#        Wheeling                      0
#        Wyoming                       2
#        Yellowstone National Park     1
#        Yellowstone Park              1
# Name: Shape Reported, Length: 8029, dtype: int64

# %% [markdown]
# ## Question 2
#
# IMDB ratings are from http://www.imdb.com/search/title?groups=top_1000&sort=user_rating&view=simple
#
# Given the IMDB movies dataset and path, use the read_csv to read the data and assign to a variable 'movies'

# %%
path = 'http://bit.ly/imdbratings'

# %%
#read the dataset

movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
#show the top 10 rows
movies[:10]
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# 0      Crime       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      Crime       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2      Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3     Action       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4      Crime       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5      Drama        96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6    Western       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7  Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8  Biography       195  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 9      Drama       139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...

# %%
#show summary of the dataset
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
#determine the dimension of the dataset
movies.shape
# Out:
# (979, 6)

# %%
#show the data types for each coloumns
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
#show all the column names
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
# rename the following columns, 'star_rating' as 'stars_rating'
# 'content_rating' as 'content' 

movies.rename(columns = {'star_rating' : 'stars_rating' , 'content_rating' : 'content'},inplace = True)
movies.columns
# Out:
# Index(['stars_rating', 'title', 'content', 'genre', 'duration', 'actors_list'], dtype='object')

# %%
#given a list called 'col_names' change all the columns names to 'col_names'
col_names = [movies.columns]
col_names
# Out:
# [Index(['stars_rating', 'title', 'content', 'genre', 'duration', 'actors_list'], dtype='object')]

# %%
#provide the statistical summary for 'star_rating' and 'duration'

movies.describe()
# Out:
#        stars_rating    duration
# count    979.000000  979.000000
# mean       7.889785  120.979571
# std        0.336069   26.218010
# min        7.400000   64.000000
# 25%        7.600000  102.000000
# 50%        7.800000  117.000000
# 75%        8.100000  134.000000
# max        9.300000  242.000000

# %%
#show the data type for column 'star_rating'

movies['stars_rating'].dtypes
# Out:
# dtype('float64')

# %%
#show the 5th row data for column 'content_rating'
movies['content'][4]
# Out:
# 'R'

# %%
#show all rows for movies duration more than 200 mins
movies[movies['duration'] >= 201]
# Out:
#      stars_rating                                          title   content  \
# 7             8.9  The Lord of the Rings: The Return of the King     PG-13
# 17            8.7                                  Seven Samurai   UNRATED
# 78            8.4                    Once Upon a Time in America         R
# 85            8.4                             Lawrence of Arabia        PG
# 142           8.3              Lagaan: Once Upon a Time in India        PG
# 157           8.2                             Gone with the Wind         G
# 204           8.1                                        Ben-Hur         G
# 445           7.9                           The Ten Commandments  APPROVED
# 476           7.8                                         Hamlet     PG-13
# 630           7.7                                      Malcolm X     PG-13
# 767           7.6                It's a Mad, Mad, Mad, Mad World  APPROVED
#
#          genre  duration                                        actors_list
# 7    Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17       Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78       Crime       229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85   Adventure       216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  Adventure       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157      Drama       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204  Adventure       212  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  Adventure       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476      Drama       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630  Biography       202  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767     Action       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
#what is the average movie duration

movies['duration'].mean()
# Out:
# 120.97957099080695

# %%
#count the number of movies where actor 'Charlton Heston' acted in
print (movies['actors_list'].str.contains(u'Charlton Heston').value_counts())
movies[movies['actors_list'].str.contains(u'Charlton Heston')]
# Out:
# False    975
# True       4
# Name: actors_list, dtype: int64
#      stars_rating                 title   content      genre  duration  \
# 175           8.2         Touch of Evil     PG-13      Crime        95
# 204           8.1               Ben-Hur         G  Adventure       212
# 368           8.0    Planet of the Apes         G  Adventure       112
# 445           7.9  The Ten Commandments  APPROVED  Adventure       220
#
#                                            actors_list
# 175  [u'Charlton Heston', u'Orson Welles', u'Janet ...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 368  [u'Charlton Heston', u'Roddy McDowall', u'Kim ...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
#what are the top 5 genre movies
print (movies['genre'].value_counts().head(5))

movies['genre'].value_counts()

import matplotlib
import matplotlib.pyplot as plt

fig , ax = plt.subplots()
moviesplt = movies['genre'].value_counts()
ax = moviesplt.plot.bar()
ax.set_title('Popularity of Every Movies Genre')
ax.ticklabel_format(useOffset=False, style='plain',axis='y')
plt.show()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Name: genre, dtype: int64

# %%
#which movie has the highest rating

print ((movies['stars_rating'].sort_values(ascending = False)).head(1))
# Out:
# 0    9.3
# Name: stars_rating, dtype: float64

# %%
#which movie has the lowest rating
movies[movies['stars_rating'] == movies['stars_rating'].min()]
# Out:
#      stars_rating                                            title  content  \
# 930           7.4                                  Man on the Moon        R
# 931           7.4                                     Mean Streets        R
# 932           7.4        Harry Potter and the Order of the Phoenix    PG-13
# 933           7.4                                      Beetlejuice       PG
# 934           7.4                             Crazy, Stupid, Love.    PG-13
# 935           7.4                                        Excalibur        R
# 936           7.4                                        True Grit      NaN
# 937           7.4                                        Labyrinth       PG
# 938           7.4                              Alice in Wonderland        G
# 939           7.4                                   Predestination        R
# 940           7.4                           Much Ado About Nothing    PG-13
# 941           7.4                                 A Bridge Too Far       PG
# 942           7.4                                  Raising Arizona    PG-13
# 943           7.4                                  The Bucket List    PG-13
# 944           7.4                              Terms of Endearment        R
# 945           7.4                                     Take Shelter        R
# 946           7.4                                  Far from Heaven    PG-13
# 947           7.4                                       Eraserhead  UNRATED
# 948           7.4                                       Frances Ha        R
# 949           7.4                                       Home Alone       PG
# 950           7.4                                            Bound        R
# 951           7.4                                    Sleepy Hollow        R
# 952           7.4                                     Pirate Radio        R
# 953           7.4                            The NeverEnding Story       PG
# 954           7.4                                            X-Men    PG-13
# 955           7.4                                 Zero Dark Thirty        R
# 956           7.4                         Manhattan Murder Mystery       PG
# 957           7.4                      National Lampoon's Vacation        R
# 958           7.4                               My Sister's Keeper    PG-13
# 959           7.4                             Deconstructing Harry        R
# 960           7.4                                 The Way Way Back    PG-13
# 961           7.4                                           Capote        R
# 962           7.4                               Driving Miss Daisy       PG
# 963           7.4                                  La Femme Nikita        R
# 964           7.4                                          Lincoln    PG-13
# 965           7.4                                        Limitless    PG-13
# 966           7.4                               The Simpsons Movie    PG-13
# 967           7.4                                         The Rock        R
# 968           7.4                              The English Patient        R
# 969           7.4                              Law Abiding Citizen        R
# 970           7.4                                      Wonder Boys        R
# 971           7.4                               Death at a Funeral        R
# 972           7.4                                   Blue Valentine    NC-17
# 973           7.4                            The Cider House Rules    PG-13
# 974           7.4                                          Tootsie       PG
# 975           7.4                      Back to the Future Part III       PG
# 976           7.4  Master and Commander: The Far Side of the World    PG-13
# 977           7.4                                      Poltergeist       PG
# 978           7.4                                      Wall Street        R
#
#          genre  duration                                        actors_list
# 930  Biography       118  [u'Jim Carrey', u'Danny DeVito', u'Gerry Becker']
# 931      Crime       112  [u'Robert De Niro', u'Harvey Keitel', u'David ...
# 932  Adventure       138  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 933     Comedy        92  [u'Alec Baldwin', u'Geena Davis', u'Michael Ke...
# 934     Comedy       118  [u'Steve Carell', u'Ryan Gosling', u'Julianne ...
# 935  Adventure       140  [u'Nigel Terry', u'Helen Mirren', u'Nicholas C...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
# 937  Adventure       101  [u'David Bowie', u'Jennifer Connelly', u'Toby ...
# 938  Animation        75  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 939      Drama        97   [u'Ethan Hawke', u'Sarah Snook', u'Noah Taylor']
# 940     Comedy       111  [u'Kenneth Branagh', u'Emma Thompson', u'Keanu...
# 941      Drama       175  [u'Sean Connery', u"Ryan O'Neal", u'Michael Ca...
# 942     Comedy        94  [u'Nicolas Cage', u'Holly Hunter', u'Trey Wils...
# 943  Adventure        97  [u'Jack Nicholson', u'Morgan Freeman', u'Sean ...
# 944     Comedy       132  [u'Shirley MacLaine', u'Debra Winger', u'Jack ...
# 945      Drama       120  [u'Michael Shannon', u'Jessica Chastain', u'Sh...
# 946      Drama       107  [u'Julianne Moore', u'Dennis Quaid', u'Dennis ...
# 947      Drama        89  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# 948     Comedy        86  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 949     Comedy       103  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 950      Crime       108  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 951      Drama       105  [u'Johnny Depp', u'Christina Ricci', u'Miranda...
# 952     Comedy       117  [u'Philip Seymour Hoffman', u'Bill Nighy', u'N...
# 953  Adventure       102  [u'Noah Hathaway', u'Barret Oliver', u'Tami St...
# 954     Action       104  [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...
# 955      Drama       157  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# 956     Comedy       104  [u'Woody Allen', u'Diane Keaton', u'Jerry Adler']
# 957     Comedy        98  [u'Chevy Chase', u"Beverly D'Angelo", u'Imogen...
# 958      Drama       109  [u'Cameron Diaz', u'Abigail Breslin', u'Alec B...
# 959     Comedy        96  [u'Woody Allen', u'Judy Davis', u'Julia Louis-...
# 960     Comedy       103  [u'Steve Carell', u'Toni Collette', u'Allison ...
# 961  Biography       114  [u'Philip Seymour Hoffman', u'Clifton Collins ...
# 962     Comedy        99  [u'Morgan Freeman', u'Jessica Tandy', u'Dan Ay...
# 963     Action       118  [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# 964  Biography       150  [u'Daniel Day-Lewis', u'Sally Field', u'David ...
# 965    Mystery       105  [u'Bradley Cooper', u'Anna Friel', u'Abbie Cor...
# 966  Animation        87  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# 967     Action       136   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# 968      Drama       162  [u'Ralph Fiennes', u'Juliette Binoche', u'Will...
# 969      Crime       109  [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']
# 970      Drama       107  [u'Michael Douglas', u'Tobey Maguire', u'Franc...
# 971     Comedy        90  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...
# 972      Drama       112  [u'Ryan Gosling', u'Michelle Williams', u'John...
# 973      Drama       126  [u'Tobey Maguire', u'Charlize Theron', u'Micha...
# 974     Comedy       116  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  Adventure       118  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976     Action       138  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977     Horror       114  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978      Crime       126  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...

# %%
# group by genre and content rating and calculate the mean for duration


movies.groupby(['genre','content'])['duration'].mean()
# Out:
# genre      content
# Action     APPROVED     143.333333
#            G            178.000000
#            GP           144.000000
#            NOT RATED    129.500000
#            PASSED        98.000000
#            PG           119.727273
#            PG-13        130.204545
#            R            123.850746
#            UNRATED      110.666667
# Adventure  APPROVED     158.333333
#            G            162.000000
#            NOT RATED    113.200000
#            PASSED       102.000000
#            PG           133.952381
#            PG-13        143.913043
#            R            124.882353
#            UNRATED      136.000000
# Animation  APPROVED      84.666667
#            G             93.150000
#            NOT RATED     91.000000
#            PG            99.360000
#            PG-13        104.200000
#            R            101.000000
#            UNRATED       89.000000
# Biography  APPROVED     111.000000
#            G            143.000000
#            GP           172.000000
#            NOT RATED     96.000000
#            PG           126.000000
#            PG-13        133.241379
#            R            132.138889
# Comedy     APPROVED     108.333333
#            G             86.000000
#            GP            91.000000
#            NC-17         95.000000
#            NOT RATED    129.875000
#            PASSED        83.666667
#            PG           100.956522
#            PG-13        106.565217
#            R            107.561644
#            UNRATED      103.750000
#            X             84.000000
# Crime      APPROVED     102.833333
#            NC-17        106.000000
#            NOT RATED    109.428571
#            PASSED       107.000000
#            PG           108.166667
#            PG-13        120.750000
#            R            127.114943
#            UNRATED      112.909091
#            X            136.000000
# Drama      APPROVED     119.583333
#            G            170.666667
#            NC-17        138.250000
#            NOT RATED    128.166667
#            PASSED       172.000000
#            PG           125.360000
#            PG-13        127.181818
#            R            125.790210
#            TV-MA        131.000000
#            UNRATED      118.777778
#            X            113.000000
# Family     G            100.000000
#            PG           115.000000
# Fantasy    R            112.000000
# Film-Noir  APPROVED      88.000000
#            NOT RATED     93.000000
#            UNRATED      111.000000
# History    UNRATED       66.000000
# Horror     APPROVED      82.500000
#            NC-17         85.000000
#            NOT RATED     75.000000
#            PG           114.000000
#            PG-13        111.500000
#            R            108.062500
#            UNRATED       98.000000
#            X             92.000000
# Mystery    APPROVED     118.000000
#            G            160.000000
#            NOT RATED    130.000000
#            PG           138.000000
#            PG-13         99.000000
#            R            111.000000
#            UNRATED       86.000000
# Sci-Fi     APPROVED      92.000000
#            PG-13         91.000000
#            R            120.666667
# Thriller   APPROVED     108.000000
#            PG           120.000000
#            R            114.333333
# Western    APPROVED     132.000000
#            NOT RATED    151.000000
#            PG           110.000000
#            PG-13        175.000000
#            R            133.666667
# Name: duration, dtype: float64
